# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 896.9/896.9 kB 22.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

# Load a model (YOLOv8)
model = YOLO("yolov8n-seg.pt")  # Make sure the path is correct

# Predict with the model (using an image URL)
results = model("cat.png")  # This URL points to an image of a bus

result_img = results[0].plot()
plt.imshow(result_img)
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/cat.png: 640x640 1 cat, 1 dog, 340.6ms
# Speed: 4.6ms preprocess, 340.6ms inference, 11.7ms postprocess per image at shape (1, 3, 640, 640)
